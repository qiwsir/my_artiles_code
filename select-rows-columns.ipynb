# %%
import pandas as pd
df = pd.read_excel("/Users/qiwsir/Documents/Codes/DataSet/major-league-baseball/MLBPlayerSalaries.xlsx")
df.head()
# Out:
#    Year           Player   Salary           Position                Team
# 0  1988        Mike Witt  1400000            Pitcher  Los Angeles Angels
# 1  1988  George Hendrick   989333         Outfielder  Los Angeles Angels
# 2  1988      Chili Davis   950000         Outfielder  Los Angeles Angels
# 3  1988    Brian Downing   900000  Designated Hitter  Los Angeles Angels
# 4  1988        Bob Boone   883000            Catcher  Los Angeles Angels

# %%
df.shape
# Out:
# (19543, 5)

# %%
df.sample()
# Out:
#       Year        Player   Salary Position               Team
# 7227  1997  Charles Nagy  3337500  Pitcher  Cleveland Indians

# %%
df.sample(n=20)
# Out:
#        Year           Player    Salary        Position                  Team
# 6396   1996       Todd Haney    127500  Second Baseman          Chicago Cubs
# 15082  2006     Mark De Rosa    675000       Shortstop         Texas Rangers
# 8161   1998       Jose Vidro    222500   Third Baseman  Washington Nationals
# 335    1988    Lenny Dykstra    305000      Outfielder         New York Mets
# 18568  2010     Jose Guillen  12000000      Outfielder    Kansas City Royals
# 16801  2008  Luis A. Mendoza    391000         Pitcher         Texas Rangers
# 18112  2010      Augie Ojeda    825000       Shortstop  Arizona Diamondbacks
# 5022   1994        Tim Spehr    132000         Catcher  Washington Nationals
# 12948  2004      Terry Adams   1700000         Pitcher     Toronto Blue Jays
# 16025  2007      Todd Helton  16600000   First Baseman      Colorado Rockies
# 10982  2001      Jason LaRue    235000         Catcher       Cincinnati Reds
# ...

# %%
import numpy as np
rs = np.random.choice(df.index.values, 20)
df20 = df.loc[rs]
df20
# Out:
#        Year              Player   Salary        Position                  Team
# 11877  2002        John Thomson  1100000         Pitcher      Colorado Rockies
# 18219  2010  Franklin Gutierrez  2312500      Outfielder      Seattle Mariners
# 16087  2007      Carlos Guillen  5000000       Shortstop        Detroit Tigers
# 14259  2005          Ryan Drese   550000         Pitcher         Texas Rangers
# 605    1988         Gary Gaetti  1425000   Third Baseman       Minnesota Twins
# 8419   1998       Chuck McElroy   817000         Pitcher      Colorado Rockies
# 9314   1999       Donnie Sadler   200000       Shortstop        Boston Red Sox
# 6927   1996         Joe Girardi  2250000         Catcher      New York Yankees
# 18041  2010     George Kottaras   408500         Catcher     Milwaukee Brewers
# 4271   1993         Gregg Olson  2300000         Pitcher     Baltimore Orioles
# 19370  2011       Jason Varitek  2000000         Catcher        Boston Red Sox
# ...

# %%
df.sample?

# %%
dfper = df.sample(frac=1)
dfper.head()
# Out:
#        Year          Player   Salary        Position                  Team
# 5550   1995    Jose Oquendo  2250000  Second Baseman   St. Louis Cardinals
# 18996  2011    Javier Lopez  2375000         Pitcher  San Francisco Giants
# 16032  2007  Byung-Hyun Kim  2500000         Pitcher      Colorado Rockies
# 4923   1994    Jerry Dipoto   135000         Pitcher     Cleveland Indians
# 9156   1999       Al Martin  2700000      Outfielder    Pittsburgh Pirates

# %%
dfper.shape
# Out:
# (19543, 5)

# %%
hdf = df.sample(frac=0.5)
hdf.shape
# Out:
# (9772, 5)

# %%
df['Weights'] = np.where(df['Year'] <= 2000, .75, .25)

# %%
df.head(2)
# Out:
#    Year           Player   Salary    Position                Team  Weights
# 0  1988        Mike Witt  1400000     Pitcher  Los Angeles Angels     0.75
# 1  1988  George Hendrick   989333  Outfielder  Los Angeles Angels     0.75

# %%
df2 = df.sample(frac=.1, random_state=111, weights="Weights")
df2
# Out:
#        Year            Player    Salary        Position  \
# 8203   1998        Tony Gwynn   4000000      Outfielder
# 2265   1990     Rick Aguilera    648000         Pitcher
# 5843   1995      Ken Caminiti   4550000   Third Baseman
# 10308  2000   Chuck Knoblauch   6000000  Second Baseman
# 3957   1993     David Justice   1775000      Outfielder
# 1998   1990       Dickie Thon   1100000       Shortstop
# 301    1988       David Valle    165000         Catcher
# 5631   1995      Greg Hansell    109000         Pitcher
# 3198   1992       Juan Guzman    220000         Pitcher
# 4524   1993          Rob Deer   2066667      Outfielder
# 19169  2011       Jim Johnson    975000         Pitcher
# 3185   1992         Jimmy Key   2275000         Pitcher
# 1088   1989        Jim Traber     90000   First Baseman
# 8972   1999    Carlos Guillen    200000       Shortstop
# 8324   1998     Kevin Stocker   1800000       Shortstop
# 3675   1992        Jack Clark   2900000   First Baseman
# ...

# %%
df2[df2['Weights']==0.75]
# Out:
#        Year             Player    Salary        Position  \
# 8203   1998         Tony Gwynn   4000000      Outfielder
# 2265   1990      Rick Aguilera    648000         Pitcher
# 5843   1995       Ken Caminiti   4550000   Third Baseman
# 10308  2000    Chuck Knoblauch   6000000  Second Baseman
# 3957   1993      David Justice   1775000      Outfielder
# 1998   1990        Dickie Thon   1100000       Shortstop
# 301    1988        David Valle    165000         Catcher
# 5631   1995       Greg Hansell    109000         Pitcher
# 3198   1992        Juan Guzman    220000         Pitcher
# 4524   1993           Rob Deer   2066667      Outfielder
# 3185   1992          Jimmy Key   2275000         Pitcher
# 1088   1989         Jim Traber     90000   First Baseman
# 8972   1999     Carlos Guillen    200000       Shortstop
# 8324   1998      Kevin Stocker   1800000       Shortstop
# 3675   1992         Jack Clark   2900000   First Baseman
# ...

# %%
df[df['Weights']==0.75]
# Out:
#        Year              Player    Salary           Position  \
# 0      1988           Mike Witt   1400000            Pitcher
# 1      1988     George Hendrick    989333         Outfielder
# 2      1988         Chili Davis    950000         Outfielder
# 3      1988       Brian Downing    900000  Designated Hitter
# 4      1988           Bob Boone    883000            Catcher
# 5      1988          Johnny Ray    857000     Second Baseman
# 6      1988           Dan Petry    785000            Pitcher
# 7      1988       Butch Wynegar    733333            Catcher
# 8      1988      Dick Schofield    552222          Shortstop
# 9      1988         Greg Minton    525000            Pitcher
# 10     1988   Tony Rafael Armas    425000         Outfielder
# 11     1988        Wally Joyner    340000      First Baseman
# 12     1988      Kirk McCaskill    262000            Pitcher
# 13     1988         Jack Howell    200000      Third Baseman
# ...

# %%
wdf = df.sample(100, weights="Weights")

# %%
wdf[wdf['Weights']==0.75]
# Out:
#        Year            Player   Salary        Position                   Team  \
# 8237   1998       Scott Rolen   750000   Third Baseman  Philadelphia Phillies
# 9139   1999     Robert Person   379000         Pitcher  Philadelphia Phillies
# 156    1988        Joey Meyer    62500   First Baseman      Milwaukee Brewers
# 9148   1999    Carlton Loewer   215000         Pitcher  Philadelphia Phillies
# 8849   1999          Rob Ryan   200000      Outfielder   Arizona Diamondbacks
# 5770   1995     Ryan Thompson   220000      Outfielder          New York Mets
# 553    1988     Larry Parrish    62500   First Baseman         Boston Red Sox
# 86     1988         Tom Henke   725000         Pitcher      Toronto Blue Jays
# 10149  2000      Jeff Fassero  2000000         Pitcher         Boston Red Sox
# 1839   1990    Edgar Martinez   108000   Third Baseman       Seattle Mariners
# 3930   1993       Pat Borders  2500000         Catcher      Toronto Blue Jays
# ...

# %%
df[df['Salary'] > 20000000].sample(frac=0.1)
# Out:
#        Year          Player    Salary       Position                Team  \
# 15320  2006  Alex Rodriguez  21680727  Third Baseman    New York Yankees
# 17848  2009   Mark Teixeira  20625000  First Baseman    New York Yankees
# 18700  2011    Vernon Wells  26187500     Outfielder  Los Angeles Angels
#
#        Weights
# 15320     0.25
# 17848     0.25
# 18700     0.25
